# %% [markdown]
# # F2 — Obtención, exploración, limpieza, transformación y validación
# **MCDI500 · Programación para la ciencia de datos**
#
# Integrantes: _completar_
#
# > Flujo exigido por el Criterio 13: obtención → exploración → limpieza → transformación → validación, con una celda narrativa que abra cada etapa. Si prefieren separar en varios archivos, mantengan el mismo orden y prefijo `F2_` (ej. `F2_Obtencion.ipynb`, `F2_Limpieza.ipynb`).

# %% [markdown]
# ## 1. Obtención / carga de los datos
#
# _Completar: fuente, licencia, y cómo se carga._

# %%
import pandas as pd
from pathlib import Path

RUTA = Path('..')/'data'/'processed'/'XXHq.csv'  # completar
df = pd.read_csv(RUTA)
df.shape
# Out:
# C:\Users\el_ma\AppData\Local\Temp\ipykernel_15844\105788544.py:5: DtypeWarning: Columns (0: q6orig) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(RUTA)
# (20103, 117)

# %% [markdown]
# ## 2. Exploración inicial
#
# _Completar: tipos de datos, primeras observaciones, distribución general._

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20103 entries, 0 to 20102
# Columns: 117 entries, site to psu
# dtypes: float64(110), int64(3), object(1), str(3)
# memory usage: 17.9+ MB
#          site       raceeth q6orig q7orig        record  orig_rec  \
# count   20103  19733.000000  19834  19419  20103.000000       0.0
# unique      1           NaN    122    356           NaN       NaN
# top        XX           NaN    506    120           NaN       NaN
# freq    20103           NaN   1355    951           NaN       NaN
# mean      NaN      5.010845    NaN    NaN  10140.386161       NaN
# std       NaN      1.832258    NaN    NaN   5863.836462       NaN
# min       NaN      1.000000    NaN    NaN      1.000000       NaN
# 25%       NaN      5.000000    NaN    NaN   5062.500000       NaN
# 50%       NaN      5.000000    NaN    NaN  10129.000000       NaN
# 75%       NaN      6.000000    NaN    NaN  15203.500000       NaN
# ...

# %% [markdown]
# ## 3. Evaluación de calidad
#
# _Completar: nulos, duplicados, valores atípicos, cardinalidad. Midan antes de decidir qué hacer._

# %%
# Nulos por columna
df.isna().sum()

# Duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Limpieza
#
# _Completar: tratamiento de nulos/duplicados, justificando cada decisión con lo medido arriba._

# %%
# df_limpio = ...

# %% [markdown]
# ## 5. Transformación
#
# _Completar: casting de tipos, encoding de categóricas, escalamiento, según el rol de cada variable._

# %%
# df_transformado = ...

# %% [markdown]
# ## 6. Validación del dataset resultante
#
# _Completar: comprobaciones de que el dataset final es íntegro y coherente.

# %%
# Verificaciones finales (shape, tipos, nulos remanentes, rangos esperados)

# %% [markdown]
# ## 7. Exportar dataset procesado
#
# Guardar en `data/processed/` — es la entrada directa de la Fase 3.

# %%
from pathlib import Path
Path('data/processed').mkdir(parents=True, exist_ok=True)
# df_transformado.to_csv('data/processed/dataset_procesado.csv', index=False)

# %% [markdown]
# ---
# **Antes de entregar:** numeración de ejecución continua — si está desordenada, `Restart Kernel and Run All Cells`.
